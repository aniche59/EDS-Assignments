# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': ['Alice','Bob','Charlie','David','Eve'],
    'Age': [25,30,35,40,45],
    'Gender': ['Female','Male','Male','Male','Female'],
    'Salary': [50000,60000,70000,80000,90000],
}
df=pd.DataFrame(data)

# %%
df.head(2)

# %%
df
# Out:
#       Name  Age  Gender  Salary
# 0    Alice   25  Female   50000
# 1      Bob   30    Male   60000
# 2  Charlie   35    Male   70000
# 3    David   40    Male   80000
# 4      Eve   45  Female   90000

# %%
df = pd.DataFrame (data=np.random.randint(0,30, (6,4)),
columns = ['col1', 'col2', 'col3', 'col4'],
index = ['A', 'B', 'C', 'D', 'E', 'F'])

# %%
df.head()
# Out:
#    col1  col2  col3  col4
# A     4    25    17    29
# B    18    10    18    25
# C    18     0    23    27
# D     2    25    11     7
# E     7     6    24    15

# %%
df.shape
# Out:
# (6, 4)

# %%
df.dtypes
# Out:
# col1    int64
# col2    int64
# col3    int64
# col4    int64
# dtype: object

# %%
df.tail()
# Out:
#    col1  col2  col3  col4
# B    18    10    18    25
# C    18     0    23    27
# D     2    25    11     7
# E     7     6    24    15
# F    16     7     1    11

# %%
df[['col2','col4']]
# Out:
#    col2  col4
# A    25    29
# B    10    25
# C     0    27
# D    25     7
# E     6    15
# F     7    11

# %%
df.loc[['C','D','E']][['col2','col3','col4']]
# Out:
#    col2  col3  col4
# C     0    23    27
# D    25    11     7
# E     6    24    15

# %%
df[['col2', 'col3', 'col4']].loc[['C', 'D', 'E']]
# Out:
#    col2  col3  col4
# C     0    23    27
# D    25    11     7
# E     6    24    15

# %%
df
# Out:
#    col1  col2  col3  col4
# A     4    25    17    29
# B    18    10    18    25
# C    18     0    23    27
# D     2    25    11     7
# E     7     6    24    15
# F    16     7     1    11

# %%
df['col5']=[10,20,30,40,50,60]

# %%
df
# Out:
#    col1  col2  col3  col4  col5
# A     4    25    17    29    10
# B    18    10    18    25    20
# C    18     0    23    27    30
# D     2    25    11     7    40
# E     7     6    24    15    50
# F    16     7     1    11    60

# %%
ser1= df['col1']+10

# %%
df['col5']=ser1

# %%
df
# Out:
#    col1  col2  col3  col4  col5
# A     4    25    17    29    14
# B    18    10    18    25    28
# C    18     0    23    27    28
# D     2    25    11     7    12
# E     7     6    24    15    17
# F    16     7     1    11    26

# %%
df.drop('col5',axis=1,inplace=True)

# %%
df
# Out:
#    col1  col2  col3  col4
# A     4    25    17    29
# B    18    10    18    25
# C    18     0    23    27
# D     2    25    11     7
# E     7     6    24    15
# F    16     7     1    11
